# %%
# !pip install roboflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/80.4 kB ? eta -:--:--
#    ---------------------------------------- 80.4/80.4 kB 4.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    - -------------------------------------- 1.7/38.8 MB 36.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 4.7/38.8 MB 49.6 MB/s eta 0:00:01
#    --------- ------------------------------ 9.7/38.8 MB 68.6 MB/s eta 0:00:01
#    --------------- ------------------------ 14.8/38.8 MB 108.8 MB/s eta 0:00:01
#    -------------------- ------------------- 20.1/38.8 MB 108.8 MB/s eta 0:00:01
#    ------------------------- -------------- 25.1/38.8 MB 131.2 MB/s eta 0:00:01
# ...

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="UyjzsJsDjpXOFtvYBdIk")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train", "tennis-ball-detection-6/tennis-ball-detection-6/train")
shutil.move("tennis-ball-detection-6/test", "tennis-ball-detection-6/tennis-ball-detection-6/test")
shutil.move("tennis-ball-detection-6/valid", "tennis-ball-detection-6/tennis-ball-detection-6/valid")
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
import torch
import torchvision
print(torch.__version__)  # Should return 2.4.1+cu124
print(torchvision.__version__)  # Should return 0.19.1+cu124 (or similar CUDA-enabled version)
print(torch.cuda.is_available())  # Should return True
# Out:
# 2.4.1+cu124
# 0.19.1+cu124
# True

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 device=0
# Out:
# Ultralytics 8.3.3 ðŸš€ Python-3.12.2 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4070, 12281MiB)
# ...
